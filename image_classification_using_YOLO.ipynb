# %% [markdown]
# <a href="https://colab.research.google.com/github/Imran1hp/image-classification-using-YOLO-model/blob/main/image_classification_using_YOLO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install opendatasets --quiet

# %%
import os
import torch
import opendatasets as od

# %% [markdown]
# Download the datasets

# %%
waste_data_url ="https://www.kaggle.com/datasets/phenomsg/waste-classification"

# %%
od.download(waste_data_url)
# Out:
# Skipping, found downloaded files in "./waste-classification" (use force=True to force download)

# %%
os.listdir()
# Out:
# ['.config',
#  'waste-classification',
#  'data',
#  'dollar-street-dataset',
#  'sample_data']

# %%
from pathlib import Path
waste_data_path = Path("waste-classification")
non_waste_data_path = Path("dollar-street-dataset")
waste_data_path , non_waste_data_path
# Out:
# (PosixPath('waste-classification'), PosixPath('dollar-street-dataset'))

# %%
def walkthrough_dir (dir_path):
  total_image = 0;
  for dirpath ,dir_names,file_names in os.walk(dir_path):
    print(f"There are {len(dir_names)} directories  and {len(file_names)} image in {dirpath}")
    total_image +=len(file_names)

  print(f"Total image {total_image}")

# %%
walkthrough_dir(waste_data_path)
# Out:
# There are 4 directories  and 0 image in waste-classification
# There are 1 directories  and 0 image in waste-classification/Hazardous
# There are 4 directories  and 0 image in waste-classification/Hazardous/Hazardous
# There are 0 directories  and 139 image in waste-classification/Hazardous/Hazardous/pesticides
# There are 0 directories  and 544 image in waste-classification/Hazardous/Hazardous/e-waste
# There are 0 directories  and 114 image in waste-classification/Hazardous/Hazardous/batteries
# There are 0 directories  and 153 image in waste-classification/Hazardous/Hazardous/paints
# There are 1 directories  and 0 image in waste-classification/Non-Recyclable
# There are 5 directories  and 0 image in waste-classification/Non-Recyclable/Non-Recyclable
# There are 0 directories  and 110 image in waste-classification/Non-Recyclable/Non-Recyclable/sanitary_napkin
# There are 0 directories  and 139 image in waste-classification/Non-Recyclable/Non-Recyclable/ceramic_product
# ...

# %%
import torchvision

non_waste_data = torchvision.datasets.CIFAR10(root ='./data', train=False ,download=True)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /tmp/ipykernel_12282/3677099117.py in <cell line: 0>()
#       1 import torchvision
#       2
# ----> 3 non_waste_data = torchvision.datasets.CIFAR10(root ='./data', train=False ,download=True)
#
# /usr/local/lib/python3.12/dist-packages/torchvision/datasets/cifar.py in __init__(self, root, train, transform, target_transform, download)
#      64
#      65         if download:
# ---> 66             self.download()
#      67
#      68         if not self._check_integrity():
#
# /usr/local/lib/python3.12/dist-packages/torchvision/datasets/cifar.py in download(self)
#     137         if self._check_integrity():
#     138             return
# --> 139         download_and_extract_archive(self.url, self.root, filename=self.filename, md5=self.tgz_md5)
#     140
#     141     def extra_repr(self) -> str:
#
# ...
